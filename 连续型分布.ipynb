# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['STFangsong']
plt.rcParams['axes.unicode_minus'] = False

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
import seaborn as sns

# 泊松分布（形状参数(越大图形越扁)，size）
# data = np.random.poisson(5,10000)

# 正态分布 np.random.normal(位置参数(最中间的数),形状参数(越大图形越扁),size(个数))
# data = np.random.normal(150,5,500)

# 指数分布（形状参数(越大图形越扁)，size）
# data = np.random.exponential(5,500)

# 均匀分布(上限，下限，size)
# data = np.random.uniform(20,100,5000)

# 伽马分布
# data = np.random.gamma(2,2,1000)

# 卡方分布
data = np.random.chisquare(2,4)

sns.histplot(data, bins = 10,kde = True)
plt.show()
